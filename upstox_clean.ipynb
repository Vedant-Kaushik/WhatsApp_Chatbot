# %% [markdown]
# # Upstox Market Data Analysis Pipeline
# This notebook consolidates the logic for:
# 1. **Discovery:** Finding Instrument Keys for Nifty 50 & BSE Indices.
# 2. **History:** Fetching 1-Year Monthly Candle Data.
# 3. **Live:** Fetching Real-Time LTP.

# %%
import os
import time
import requests
import gzip
import json
import io
import pandas as pd
import upstox_client
from dotenv import load_dotenv

# Load secrets
load_dotenv()
ACCESS_TOKEN = os.getenv("UPSTOX_ACCESS_TOKEN")

# Configure APIs
configuration = upstox_client.Configuration()
configuration.access_token = ACCESS_TOKEN
api_client = upstox_client.ApiClient(configuration)

# Initialize BOTH APIs
history_api = upstox_client.HistoryV3Api(api_client)
# Note: User requested MarketQuoteV3Api logic, using MarketQuoteApi as standard SDK class
market_api = upstox_client.MarketQuoteV3Api(api_client)

print("APIs Initialized.")
# Out:
# APIs Initialized.

# %% [markdown]
# ## Step 1: Instrument Discovery

# %%
NIFTY_50_SYMBOLS = [
    "RELIANCE", "TCS", "HDFC", "INFY", "ITC", "LT", "HDFCBANK", "ICICIBANK", "KOTAKBANK", "SBIN",
    "BHARTIARTL", "ASIANPAINT", "MARUTI", "TITAN", "BAJFINANCE", "HCLTECH", "ADANIENT", "SUNPHARMA",
    "ONGC", "NTPC", "TATAMOTORS", "POWERGRID", "ULTRACEMCO", "JSWSTEEL", "TATASTEEL", "M&M",
    "WIPRO", "COALINDIA", "BAJAJFINSV", "BPCL", "NESTLEIND", "BRITANNIA", "TECHM", "EICHERMOT",
    "ADANIPORTS", "GRASIM", "HINDALCO", "DRREDDY", "DIVISLAB", "CIPLA", "APOLLOHOSP", "TATACONSUM",
    "INDUSINDBK", "UPL", "HEROMOTOCO", "BAJAJ-AUTO", "HDFCLIFE", "SBILIFE", "AXISBANK", "LTIM"
]

def get_instrument_keys():
    # 1. Download NSE Master
    print("Downloading NSE Master...")
    nse_resp = requests.get("https://assets.upstox.com/market-quote/instruments/exchange/NSE.json.gz")
    with gzip.GzipFile(fileobj=io.BytesIO(nse_resp.content)) as f:
        nse_data = json.load(f)
        
    # 2. Download BSE Master
    print("Downloading BSE Master...")
    bse_resp = requests.get("https://assets.upstox.com/market-quote/instruments/exchange/BSE.json.gz")
    with gzip.GzipFile(fileobj=io.BytesIO(bse_resp.content)) as f:
        bse_data = json.load(f)
        
    keys = []
    
    # Filter Nifty 50 Stocks
    for item in nse_data:
        if item['segment'] == 'NSE_EQ' and item['trading_symbol'] in NIFTY_50_SYMBOLS:
            keys.append(item['instrument_key'])
            
    # Filter ALL BSE Indices
    for item in bse_data:
        if item['segment'] == 'BSE_INDEX':
            keys.append(item['instrument_key'])
            
    return list(set(keys)) # Remove duplicates

target_keys = get_instrument_keys()
print(f"Target Instruments: {len(target_keys)}")
# Out:
# Downloading NSE Master...
# Downloading BSE Master...
# Target Instruments: 117

# %% [markdown]
# ## Step 2: Fetch Historical Data (Monthly Candles)

# %%
candle_data_store = []

print("Fetching candles")
for key in target_keys:
    try:
        response = history_api.get_historical_candle_data1(
            key,
            "months", 
            "1", 
            "2026-02-06", # Today
            "2025-01-01"  # Start Date
        )
        
        candle_data_store.append({
            "instrument_key": key,
            "candles": response.data.candles
        })
            
    except Exception as e:
        print(f"Failed: {key} - {e}")
        

print(f"Done. History for {len(candle_data_store)} instruments.")
# Out:
# Fetching candles
# Done. History for 117 instruments.

# %% [markdown]
# ## Step 3: Fetch Live LTP (Loop)

# %%
ltp_with_names = {}

print("Fetching Live LTP...")

for instrument_key in target_keys:
    
    try:
        # For a single instrument
        response = market_api.get_ltp(instrument_key=instrument_key)
        actual_keys = list(response.data.keys())
        ltp_with_names[instrument_key] = response.data[actual_keys[0]].last_price

    except Exception as e:
        # Using generic Exception to catch all
        print(f"Exception when calling MarketQuoteApi->get_ltp: {e}")

print(f"Fetched LTP for {len(ltp_with_names)} instruments.")
# Out:
# Fetching Live LTP...
# Fetched LTP for 117 instruments.

# %%
ltp_with_names
# Out:
# {'BSE_INDEX|BBGEFS': 4510.53,
#  'BSE_INDEX|BSEHC': 42158.43,
#  'BSE_INDEX|SNXN30': 40244.05,
#  'BSE_INDEX|FOCMID': 24343.74,
#  'NSE_EQ|INE467B01029': 2991.5,
#  'BSE_INDEX|BSEFMC': 18622.19,
#  'BSE_INDEX|INDSTR': 14661.68,
#  'BSE_INDEX|METAL': 39222.37,
#  'NSE_EQ|INE095A01012': 913.5,
#  'BSE_INDEX|SMEIPO': 87861.85,
#  'NSE_EQ|INE437A01024': 7122.0,
#  'BSE_INDEX|INSLDR': 15119.61,
#  'NSE_EQ|INE075A01022': 233.39,
#  'NSE_EQ|INE021A01026': 2432.1,
#  'BSE_INDEX|PSUBNK': 5031.95,
#  'BSE_INDEX|TELCOM': 3014.29,
#  'BSE_INDEX|BSEDSI': 1078.16,
#  'BSE_INDEX|PRECON': 5234.23,
#  'NSE_EQ|INE522F01014': 431.85,
#  'NSE_EQ|INE002A01018': 1443.4,
#  'NSE_EQ|INE089A01031': 1244.9,
#  'NSE_EQ|INE585B01010': 15059.0,
#  'BSE_INDEX|BANKEX': 67536.37,
#  'BSE_INDEX|LCTMCI': 9480.83,
#  'BSE_INDEX|CAPINS': 2390.38,
#  'BSE_INDEX|INFRA': 588.01,
#  'BSE_INDEX|BSE500': 36695.11,
#  'BSE_INDEX|BSESER': 1543.65,
#  'BSE_INDEX|SS6535': 35002.66,
#  'NSE_EQ|INE038A01020': 935.45,
#  'NSE_EQ|INE009A01021': 1520.2,
#  'BSE_INDEX|INTECO': 2979.49,
#  'BSE_INDEX|BSEMOI': 2187.67,
#  'BSE_INDEX|BSE200': 11613.55,
#  'BSE_INDEX|SMLSEL': 7720.4,
#  'NSE_EQ|INE481G01011': 12773.0,
#  'BSE_INDEX|REALTY': 6392.56,
#  'BSE_INDEX|BS1000': 10877.13,
#  'NSE_EQ|INE158A01026': 5766.0,
#  'NSE_EQ|INE047A01021': 2863.9,
#  'NSE_EQ|INE628A01036': 747.65,
#  'NSE_EQ|INE423A01024': 2236.6,
#  'BSE_INDEX|SNSX60': 34431.1,
#  'NSE_EQ|INE795G01014': 720.7,
#  'BSE_INDEX|BSE100': 26869.85,
#  'BSE_INDEX|SELIPO': 4366.18,
#  'BSE_INDEX|MIDSEL': 17183.56,
#  'NSE_EQ|INE752E01010': 289.35,
#  'NSE_EQ|INE019A01038': 1239.8,
#  'NSE_EQ|INE733E01010': 367.0,
#  'BSE_INDEX|OILGAS': 29041.25,
#  'BSE_INDEX|BSEQUI': 1852.12,
#  'NSE_EQ|INE238A01034': 1330.6,
#  'NSE_EQ|INE123W01016': 2017.8,
#  'NSE_EQ|INE280A01028': 4097.6,
#  'NSE_EQ|INE081A01020': 197.76,
#  'NSE_EQ|INE029A01011': 382.05,
#  'NSE_EQ|INE742F01042': 1570.2,
#  'BSE_INDEX|ENERGY': 12201.47,
#  'BSE_INDEX|QUAL50': 21524.96,
#  'BSE_INDEX|BSEEVI': 1098.27,
#  'BSE_INDEX|SENEQW': 82248.91,
#  'NSE_EQ|INE361B01024': 6141.5,
#  'BSE_INDEX|FINSER': 13099.29,
#  'BSE_INDEX|COMDTY': 8267.25,
#  'NSE_EQ|INE214T01019': 5683.5,
#  'NSE_EQ|INE090A01021': 1396.5,
#  'NSE_EQ|INE918I01026': 2000.1,
#  'NSE_EQ|INE062A01020': 1073.5,
#  'NSE_EQ|INE860A01027': 1610.0,
#  'NSE_EQ|INE018A01030': 4063.3,
#  'NSE_EQ|INE101A01026': 3572.0,
#  'NSE_EQ|INE917I01010': 9647.0,
#  'BSE_INDEX|BSEPSU': 21550.3,
#  'BSE_INDEX|POWER': 6769.68,
#  'BSE_INDEX|UTILS': 5317.8,
#  'BSE_INDEX|LMI250': 11000.65,
#  'BSE_INDEX|FOCIT': 42294.09,
#  'NSE_EQ|INE040A01034': 949.7,
#  'BSE_INDEX|SENSEX': 83313.93,
#  'BSE_INDEX|BSEPBI': 21098.2,
#  'NSE_EQ|INE154A01025': 310.2,
#  'BSE_INDEX|MOME50': 43625.39,
#  'NSE_EQ|INE216A01030': 5889.5,
#  'NSE_EQ|INE044A01036': 1702.6,
#  'NSE_EQ|INE669C01036': 1646.2,
#  'BSE_INDEX|BHRT22': 9385.73,
#  'NSE_EQ|INE397D01024': 1992.4,
#  'NSE_EQ|INE192A01025': 1155.9,
#  'BSE_INDEX|BSELVI': 1847.35,
#  'BSE_INDEX|IND150': 19197.98,
#  'BSE_INDEX|SNXT50': 85874.68,
#  'NSE_EQ|INE059A01026': 1333.3,
#  'BSE_INDEX|BSECD': 57468.28,
#  'BSE_INDEX|SML250': 6338.08,
#  'NSE_EQ|INE213A01029': 269.2,
#  'BSE_INDEX|200EQW': 13220.52,
#  'BSE_INDEX|BSEIPO': 15102.77,
#  'BSE_INDEX|MFG': 1090.67,
#  'NSE_EQ|INE296A01032': 964.75,
#  'BSE_INDEX|TECK': 17637.19,
#  'BSE_INDEX|SENSEX50': 26771.84,
#  'NSE_EQ|INE066A01021': 7209.5,
#  'BSE_INDEX|BSECG': 67479.01,
#  'BSE_INDEX|POWENE': 3951.68,
#  'BSE_INDEX|AUTO': 61346.31,
#  'BSE_INDEX|CPSE': 3994.83,
#  'BSE_INDEX|DIVY50': 3710.85,
#  'BSE_INDEX|INDDEF': 6637.48,
#  'BSE_INDEX|BSEIT': 34843.08,
#  'BSE_INDEX|MSL400': 11774.63,
#  'BSE_INDEX|CONDIS': 9530.46,
#  'BSE_INDEX|DFRGRI': 1660.8,
#  'BSE_INDEX|MID150': 16083.36,
#  'BSE_INDEX|ESG100': 428.56,
#  'NSE_EQ|INE237A01036': 408.75,
#  'NSE_EQ|INE239A01024': 1303.5}

# %% [markdown]
# ## Now we have ltp and candle data from upstox for 117 instruments now we ned to map it and make a clean prompt for LLM

# %%
prompt = "Analyze these stocks,given amount and time to invest\n\n amount :50K and time is 3 months\n\n\n mae sure you use few words in 2 lines"

for candle_data in candle_data_store:
    key = candle_data['instrument_key']
    candles = candle_data['candles']
    ltp = ltp_with_names[key] # Current Price
    
    # 1. Get History
    closes = [c[4] for c in candles] # Extract just the Close prices
    
    # 2. Calculate Long Term Return (1 Year)
    # closes[-1] is the oldest candle (Jan 2025)
    start_price = closes[-1]
    ret_1y = ((ltp - start_price) / start_price) * 100
    
    # 3. Simple Trend (Current vs 3-Month Avg)
    avg_3m = sum(closes[:3]) / 3
    trend = "BULLISH" if ltp > avg_3m else "BEARISH"
    
    # 4. Add to Prompt (Clean Format)
    prompt += f"Stock: {key}\n"
    prompt += f"Price: {ltp} | 1Y Return: {ret_1y:.2f}%\n"
    prompt += f"Trend: {trend} (vs 3M Avg: {avg_3m:.2f})\n\n"
    
print(prompt)
# Out:
# Analyze these stocks,given amount and time to invest
#
#  amount :50K and time is 3 months
#
#
#  mae sure you use few words in 2 linesStock: BSE_INDEX|BBGEFS
# Price: 4510.53 | 1Y Return: 11.21%
# Trend: BULLISH (vs 3M Avg: 4498.05)
#
# Stock: BSE_INDEX|BSEHC
# Price: 42158.43 | 1Y Return: 0.85%
# Trend: BEARISH (vs 3M Avg: 42436.03)
#
# Stock: BSE_INDEX|SNXN30
# Price: 40244.05 | 1Y Return: 13.56%
# Trend: BEARISH (vs 3M Avg: 40250.18)
#
# Stock: BSE_INDEX|FOCMID
# Price: 24343.74 | 1Y Return: 9.39%
# Trend: BEARISH (vs 3M Avg: 24351.09)
#
# Stock: NSE_EQ|INE467B01029
# Price: 2991.5 | 1Y Return: -27.26%
# Trend: BEARISH (vs 3M Avg: 3107.20)
#
# Stock: BSE_INDEX|BSEFMC
# Price: 18622.19 | 1Y Return: -9.40%
# Trend: BEARISH (vs 3M Avg: 19235.16)
#
# Stock: BSE_INDEX|INDSTR
# Price: 14661.68 | 1Y Return: 6.00%
# Trend: BULLISH (vs 3M Avg: 14589.71)
#
# Stock: BSE_INDEX|METAL
# Price: 39222.37 | 1Y Return: 37.29%
# Trend: BULLISH (vs 3M Avg: 38293.09)
#
# Stock: NSE_EQ|INE095A01012
# Price: 913.5 | 1Y Return: -7.84%
# Trend: BULLISH (vs 3M Avg: 891.27)
#
# Stock: BSE_INDEX|SMEIPO
# Price: 87861.85 | 1Y Return: -17.62%
# Trend: BEARISH (vs 3M Avg: 89789.55)
#
# Stock: NSE_EQ|INE437A01024
# Price: 7122.0 | 1Y Return: 4.57%
# Trend: BULLISH (vs 3M Avg: 7041.67)
#
# Stock: BSE_INDEX|INSLDR
# Price: 15119.61 | 1Y Return: -0.06%
# Trend: BEARISH (vs 3M Avg: 15159.49)
#
# Stock: NSE_EQ|INE075A01022
# Price: 233.39 | 1Y Return: -25.17%
# Trend: BEARISH (vs 3M Avg: 244.52)
#
# Stock: NSE_EQ|INE021A01026
# Price: 2432.1 | 1Y Return: 5.71%
# Trend: BEARISH (vs 3M Avg: 2543.30)
#
# Stock: BSE_INDEX|PSUBNK
# Price: 5031.95 | 1Y Return: 39.32%
# Trend: BULLISH (vs 3M Avg: 4988.07)
#
# Stock: BSE_INDEX|TELCOM
# Price: 3014.29 | 1Y Return: 9.44%
# Trend: BEARISH (vs 3M Avg: 3037.30)
#
# Stock: BSE_INDEX|BSEDSI
# Price: 1078.16 | 1Y Return: 10.84%
# Trend: BULLISH (vs 3M Avg: 1065.89)
#
# Stock: BSE_INDEX|PRECON
# Price: 5234.23 | 1Y Return: 3.60%
# Trend: BEARISH (vs 3M Avg: 5238.67)
#
# Stock: NSE_EQ|INE522F01014
# Price: 431.85 | 1Y Return: 9.08%
# Trend: BULLISH (vs 3M Avg: 423.87)
#
# Stock: NSE_EQ|INE002A01018
# Price: 1443.4 | 1Y Return: 14.09%
# Trend: BEARISH (vs 3M Avg: 1469.73)
#
# Stock: NSE_EQ|INE089A01031
# Price: 1244.9 | 1Y Return: 2.26%
# Trend: BULLISH (vs 3M Avg: 1244.80)
#
# Stock: NSE_EQ|INE585B01010
# Price: 15059.0 | 1Y Return: 22.32%
# Trend: BEARISH (vs 3M Avg: 15451.67)
#
# Stock: BSE_INDEX|BANKEX
# Price: 67536.37 | 1Y Return: 20.05%
# Trend: BULLISH (vs 3M Avg: 67121.78)
#
# Stock: BSE_INDEX|LCTMCI
# Price: 9480.83 | 1Y Return: 9.32%
# Trend: BEARISH (vs 3M Avg: 9491.00)
#
# Stock: BSE_INDEX|CAPINS
# Price: 2390.38 | 1Y Return: 24.31%
# Trend: BULLISH (vs 3M Avg: 2380.88)
#
# Stock: BSE_INDEX|INFRA
# Price: 588.01 | 1Y Return: 1.05%
# Trend: BULLISH (vs 3M Avg: 578.89)
#
# Stock: BSE_INDEX|BSE500
# Price: 36695.11 | 1Y Return: 8.05%
# Trend: BEARISH (vs 3M Avg: 36774.52)
#
# Stock: BSE_INDEX|BSESER
# Price: 1543.65 | 1Y Return: 17.01%
# Trend: BULLISH (vs 3M Avg: 1516.91)
#
# Stock: BSE_INDEX|SS6535
# Price: 35002.66 | 1Y Return: 9.61%
# Trend: BEARISH (vs 3M Avg: 35081.82)
#
# Stock: NSE_EQ|INE038A01020
# Price: 935.45 | 1Y Return: 57.40%
# Trend: BULLISH (vs 3M Avg: 928.25)
#
# Stock: NSE_EQ|INE009A01021
# Price: 1520.2 | 1Y Return: -19.13%
# Trend: BEARISH (vs 3M Avg: 1592.20)
#
# Stock: BSE_INDEX|INTECO
# Price: 2979.49 | 1Y Return: 12.41%
# Trend: BEARISH (vs 3M Avg: 3021.57)
#
# Stock: BSE_INDEX|BSEMOI
# Price: 2187.67 | 1Y Return: 5.66%
# Trend: BULLISH (vs 3M Avg: 2176.45)
#
# Stock: BSE_INDEX|BSE200
# Price: 11613.55 | 1Y Return: 8.89%
# Trend: BEARISH (vs 3M Avg: 11621.58)
#
# Stock: BSE_INDEX|SMLSEL
# Price: 7720.4 | 1Y Return: 4.20%
# Trend: BEARISH (vs 3M Avg: 7820.24)
#
# Stock: NSE_EQ|INE481G01011
# Price: 12773.0 | 1Y Return: 11.19%
# Trend: BULLISH (vs 3M Avg: 12417.00)
#
# Stock: BSE_INDEX|REALTY
# Price: 6392.56 | 1Y Return: -10.60%
# Trend: BEARISH (vs 3M Avg: 6434.10)
#
# Stock: BSE_INDEX|BS1000
# Price: 10877.13 | 1Y Return: 5.86%
# Trend: BEARISH (vs 3M Avg: 10901.44)
#
# Stock: NSE_EQ|INE158A01026
# Price: 5766.0 | 1Y Return: 32.88%
# Trend: BULLISH (vs 3M Avg: 5690.33)
#
# Stock: NSE_EQ|INE047A01021
# Price: 2863.9 | 1Y Return: 14.15%
# Trend: BULLISH (vs 3M Avg: 2837.30)
#
# Stock: NSE_EQ|INE628A01036
# Price: 747.65 | 1Y Return: 23.83%
# Trend: BEARISH (vs 3M Avg: 748.92)
#
# Stock: NSE_EQ|INE423A01024
# Price: 2236.6 | 1Y Return: -2.24%
# Trend: BULLISH (vs 3M Avg: 2165.57)
#
# Stock: BSE_INDEX|SNSX60
# Price: 34431.1 | 1Y Return: 8.71%
# Trend: BEARISH (vs 3M Avg: 34526.52)
#
# Stock: NSE_EQ|INE795G01014
# Price: 720.7 | 1Y Return: 12.95%
# Trend: BEARISH (vs 3M Avg: 733.85)
#
# Stock: BSE_INDEX|BSE100
# Price: 26869.85 | 1Y Return: 9.11%
# Trend: BEARISH (vs 3M Avg: 26916.98)
#
# Stock: BSE_INDEX|SELIPO
# Price: 4366.18 | 1Y Return: -0.94%
# Trend: BEARISH (vs 3M Avg: 4415.55)
#
# Stock: BSE_INDEX|MIDSEL
# Price: 17183.56 | 1Y Return: 7.97%
# Trend: BEARISH (vs 3M Avg: 17184.03)
#
# Stock: NSE_EQ|INE752E01010
# Price: 289.35 | 1Y Return: -4.08%
# Trend: BULLISH (vs 3M Avg: 270.15)
#
# Stock: NSE_EQ|INE019A01038
# Price: 1239.8 | 1Y Return: 31.20%
# Trend: BULLISH (vs 3M Avg: 1206.33)
#
# Stock: NSE_EQ|INE733E01010
# Price: 367.0 | 1Y Return: 13.27%
# Trend: BULLISH (vs 3M Avg: 350.85)
#
# Stock: BSE_INDEX|OILGAS
# Price: 29041.25 | 1Y Return: 14.21%
# Trend: BULLISH (vs 3M Avg: 28621.42)
#
# Stock: BSE_INDEX|BSEQUI
# Price: 1852.12 | 1Y Return: 6.09%
# Trend: BEARISH (vs 3M Avg: 1868.57)
#
# Stock: NSE_EQ|INE238A01034
# Price: 1330.6 | 1Y Return: 34.94%
# Trend: BULLISH (vs 3M Avg: 1323.47)
#
# Stock: NSE_EQ|INE123W01016
# Price: 2017.8 | 1Y Return: 36.01%
# Trend: BULLISH (vs 3M Avg: 2017.07)
#
# Stock: NSE_EQ|INE280A01028
# Price: 4097.6 | 1Y Return: 17.40%
# Trend: BULLISH (vs 3M Avg: 4042.17)
#
# Stock: NSE_EQ|INE081A01020
# Price: 197.76 | 1Y Return: 46.90%
# Trend: BULLISH (vs 3M Avg: 190.32)
#
# Stock: NSE_EQ|INE029A01011
# Price: 382.05 | 1Y Return: 46.32%
# Trend: BULLISH (vs 3M Avg: 376.85)
#
# Stock: NSE_EQ|INE742F01042
# Price: 1570.2 | 1Y Return: 42.83%
# Trend: BULLISH (vs 3M Avg: 1486.60)
#
# Stock: BSE_INDEX|ENERGY
# Price: 12201.47 | 1Y Return: 12.19%
# Trend: BULLISH (vs 3M Avg: 12116.19)
#
# Stock: BSE_INDEX|QUAL50
# Price: 21524.96 | 1Y Return: 2.47%
# Trend: BEARISH (vs 3M Avg: 21636.37)
#
# Stock: BSE_INDEX|BSEEVI
# Price: 1098.27 | 1Y Return: 27.32%
# Trend: BULLISH (vs 3M Avg: 1076.39)
#
# Stock: BSE_INDEX|SENEQW
# Price: 82248.91 | 1Y Return: 8.56%
# Trend: BULLISH (vs 3M Avg: 81909.00)
#
# Stock: NSE_EQ|INE361B01024
# Price: 6141.5 | 1Y Return: 10.11%
# Trend: BEARISH (vs 3M Avg: 6195.00)
#
# Stock: BSE_INDEX|FINSER
# Price: 13099.29 | 1Y Return: 18.50%
# Trend: BULLISH (vs 3M Avg: 13070.67)
#
# Stock: BSE_INDEX|COMDTY
# Price: 8267.25 | 1Y Return: 16.97%
# Trend: BULLISH (vs 3M Avg: 8170.36)
#
# Stock: NSE_EQ|INE214T01019
# Price: 5683.5 | 1Y Return: -3.90%
# Trend: BEARISH (vs 3M Avg: 5907.17)
#
# Stock: NSE_EQ|INE090A01021
# Price: 1396.5 | 1Y Return: 11.47%
# Trend: BULLISH (vs 3M Avg: 1364.80)
#
# Stock: NSE_EQ|INE918I01026
# Price: 2000.1 | 1Y Return: 15.21%
# Trend: BULLISH (vs 3M Avg: 1997.53)
#
# Stock: NSE_EQ|INE062A01020
# Price: 1073.5 | 1Y Return: 38.89%
# Trend: BULLISH (vs 3M Avg: 1044.28)
#
# Stock: NSE_EQ|INE860A01027
# Price: 1610.0 | 1Y Return: -6.69%
# Trend: BEARISH (vs 3M Avg: 1642.97)
#
# Stock: NSE_EQ|INE018A01030
# Price: 4063.3 | 1Y Return: 13.90%
# Trend: BULLISH (vs 3M Avg: 4026.37)
#
# Stock: NSE_EQ|INE101A01026
# Price: 3572.0 | 1Y Return: 19.47%
# Trend: BULLISH (vs 3M Avg: 3571.00)
#
# Stock: NSE_EQ|INE917I01010
# Price: 9647.0 | 1Y Return: 9.03%
# Trend: BULLISH (vs 3M Avg: 9529.17)
#
# Stock: BSE_INDEX|BSEPSU
# Price: 21550.3 | 1Y Return: 17.17%
# Trend: BULLISH (vs 3M Avg: 21200.89)
#
# Stock: BSE_INDEX|POWER
# Price: 6769.68 | 1Y Return: 3.30%
# Trend: BULLISH (vs 3M Avg: 6555.15)
#
# Stock: BSE_INDEX|UTILS
# Price: 5317.8 | 1Y Return: 4.01%
# Trend: BULLISH (vs 3M Avg: 5156.74)
#
# Stock: BSE_INDEX|LMI250
# Price: 11000.65 | 1Y Return: 8.91%
# Trend: BEARISH (vs 3M Avg: 11012.33)
#
# Stock: BSE_INDEX|FOCIT
# Price: 42294.09 | 1Y Return: -15.60%
# Trend: BEARISH (vs 3M Avg: 43604.23)
#
# Stock: NSE_EQ|INE040A01034
# Price: 949.7 | 1Y Return: 11.81%
# Trend: BEARISH (vs 3M Avg: 956.72)
#
# Stock: BSE_INDEX|SENSEX
# Price: 83313.93 | 1Y Return: 7.50%
# Trend: BEARISH (vs 3M Avg: 83601.44)
#
# Stock: BSE_INDEX|BSEPBI
# Price: 21098.2 | 1Y Return: 19.30%
# Trend: BULLISH (vs 3M Avg: 21009.47)
#
# Stock: NSE_EQ|INE154A01025
# Price: 310.2 | 1Y Return: -30.68%
# Trend: BEARISH (vs 3M Avg: 345.12)
#
# Stock: BSE_INDEX|MOME50
# Price: 43625.39 | 1Y Return: 1.61%
# Trend: BULLISH (vs 3M Avg: 43606.39)
#
# Stock: NSE_EQ|INE216A01030
# Price: 5889.5 | 1Y Return: 14.81%
# Trend: BEARISH (vs 3M Avg: 5927.00)
#
# Stock: NSE_EQ|INE044A01036
# Price: 1702.6 | 1Y Return: -2.37%
# Trend: BULLISH (vs 3M Avg: 1672.53)
#
# Stock: NSE_EQ|INE669C01036
# Price: 1646.2 | 1Y Return: -1.69%
# Trend: BEARISH (vs 3M Avg: 1660.07)
#
# Stock: BSE_INDEX|BHRT22
# Price: 9385.73 | 1Y Return: 13.23%
# Trend: BULLISH (vs 3M Avg: 9265.44)
#
# Stock: NSE_EQ|INE397D01024
# Price: 1992.4 | 1Y Return: 22.51%
# Trend: BEARISH (vs 3M Avg: 2022.23)
#
# Stock: NSE_EQ|INE192A01025
# Price: 1155.9 | 1Y Return: 12.81%
# Trend: BEARISH (vs 3M Avg: 1160.60)
#
# Stock: BSE_INDEX|BSELVI
# Price: 1847.35 | 1Y Return: 5.97%
# Trend: BEARISH (vs 3M Avg: 1856.99)
#
# Stock: BSE_INDEX|IND150
# Price: 19197.98 | 1Y Return: 3.90%
# Trend: BEARISH (vs 3M Avg: 19200.62)
#
# Stock: BSE_INDEX|SNXT50
# Price: 85874.68 | 1Y Return: 10.59%
# Trend: BULLISH (vs 3M Avg: 85729.99)
#
# Stock: NSE_EQ|INE059A01026
# Price: 1333.3 | 1Y Return: -9.88%
# Trend: BEARISH (vs 3M Avg: 1389.53)
#
# Stock: BSE_INDEX|BSECD
# Price: 57468.28 | 1Y Return: -0.66%
# Trend: BEARISH (vs 3M Avg: 57600.72)
#
# Stock: BSE_INDEX|SML250
# Price: 6338.08 | 1Y Return: -0.48%
# Trend: BEARISH (vs 3M Avg: 6421.76)
#
# Stock: NSE_EQ|INE213A01029
# Price: 269.2 | 1Y Return: 2.51%
# Trend: BULLISH (vs 3M Avg: 259.51)
#
# Stock: BSE_INDEX|200EQW
# Price: 13220.52 | 1Y Return: 8.43%
# Trend: BULLISH (vs 3M Avg: 13188.12)
#
# Stock: BSE_INDEX|BSEIPO
# Price: 15102.77 | 1Y Return: 3.11%
# Trend: BEARISH (vs 3M Avg: 15230.83)
#
# Stock: BSE_INDEX|MFG
# Price: 1090.67 | 1Y Return: 9.79%
# Trend: BEARISH (vs 3M Avg: 1093.18)
#
# Stock: NSE_EQ|INE296A01032
# Price: 964.75 | 1Y Return: 22.35%
# Trend: BULLISH (vs 3M Avg: 960.47)
#
# Stock: BSE_INDEX|TECK
# Price: 17637.19 | 1Y Return: -8.02%
# Trend: BEARISH (vs 3M Avg: 18131.49)
#
# Stock: BSE_INDEX|SENSEX50
# Price: 26771.84 | 1Y Return: 8.77%
# Trend: BEARISH (vs 3M Avg: 26840.41)
#
# Stock: NSE_EQ|INE066A01021
# Price: 7209.5 | 1Y Return: 38.80%
# Trend: BEARISH (vs 3M Avg: 7214.83)
#
# Stock: BSE_INDEX|BSECG
# Price: 67479.01 | 1Y Return: 4.57%
# Trend: BULLISH (vs 3M Avg: 67085.91)
#
# Stock: BSE_INDEX|POWENE
# Price: 3951.68 | 1Y Return: 9.36%
# Trend: BULLISH (vs 3M Avg: 3871.23)
#
# Stock: BSE_INDEX|AUTO
# Price: 61346.31 | 1Y Return: 19.06%
# Trend: BULLISH (vs 3M Avg: 61068.80)
#
# Stock: BSE_INDEX|CPSE
# Price: 3994.83 | 1Y Return: 10.29%
# Trend: BULLISH (vs 3M Avg: 3934.13)
#
# Stock: BSE_INDEX|DIVY50
# Price: 3710.85 | 1Y Return: 0.82%
# Trend: BULLISH (vs 3M Avg: 2463.88)
#
# Stock: BSE_INDEX|INDDEF
# Price: 6637.48 | 1Y Return: -3.95%
# Trend: BULLISH (vs 3M Avg: 4515.99)
#
# Stock: BSE_INDEX|BSEIT
# Price: 34843.08 | 1Y Return: -16.95%
# Trend: BEARISH (vs 3M Avg: 36064.58)
#
# Stock: BSE_INDEX|MSL400
# Price: 11774.63 | 1Y Return: 4.89%
# Trend: BEARISH (vs 3M Avg: 11832.83)
#
# Stock: BSE_INDEX|CONDIS
# Price: 9530.46 | 1Y Return: 3.86%
# Trend: BULLISH (vs 3M Avg: 9523.64)
#
# Stock: BSE_INDEX|DFRGRI
# Price: 1660.8 | 1Y Return: 20.64%
# Trend: BEARISH (vs 3M Avg: 1666.92)
#
# Stock: BSE_INDEX|MID150
# Price: 16083.36 | 1Y Return: 7.71%
# Trend: BEARISH (vs 3M Avg: 16100.06)
#
# Stock: BSE_INDEX|ESG100
# Price: 428.56 | 1Y Return: 10.37%
# Trend: BEARISH (vs 3M Avg: 429.36)
#
# Stock: NSE_EQ|INE237A01036
# Price: 408.75 | 1Y Return: 7.48%
# Trend: BEARISH (vs 3M Avg: 418.98)
#
# Stock: NSE_EQ|INE239A01024
# Price: 1303.5 | 1Y Return: 12.70%
# Trend: BEARISH (vs 3M Avg: 1307.97)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm=ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0.3,
)

# %%
llm.invoke(prompt).content
# Out:
# 'Given the short 3-month timeframe, focus on bullish stocks with positive 1Y returns.\n\nAllocate funds to PSUBNK, METAL, INE038A01020, INE123W01016, INE081A01020, INE742F01042, ENERGY, and BSEEVI for potential short-term gains.'
